# %%
import numpy as np
from numpy import linalg as LA
from keras.datasets import mnist, fashion_mnist
import pandas as pd
from keras.layers import Input, Dense, concatenate 
from keras.models import Model, load_model
from keras import optimizers
from keras import backend as K
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics.cluster import normalized_mutual_info_score
from tqdm import tqdm
from sklearn.decomposition import PCA
import glob
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from keras import objectives
#from MulticoreTSNE import MulticoreTSNE as TSNEGPU
import tensorflow as tf
from sklearn import manifold
from sklearn.decomposition import PCA
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from scipy.stats import mode
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from tensorflow import keras



def fashion_scatter(x, colors):
    import seaborn as sns
    import matplotlib.pyplot as plt
    import matplotlib.patheffects as PathEffects
    # on choisit une palette de de couleur avec seaborn
    num_classes = len(np.unique(colors))
    palette = np.array(sns.color_palette("hls", num_classes))

    # on crée le scatter-plot
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:, 0], x[:, 1], lw=0, s=40, c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')

    # on ajoute les labels pour chaque digit correspondant au label
    txts = []

    for i in range(num_classes):
        # position de chaque label au milieu des points

        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth=5, foreground="w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts


def kmeans_fit(X,y_train):
    import time
    from sklearn.metrics.cluster import adjusted_mutual_info_score
    from sklearn.metrics.cluster import normalized_mutual_info_score
    from sklearn.metrics.cluster import adjusted_rand_score
    
    #(x_train_encoded, y_train), (x_test_encoded, y_train) = get_encoded_data()

    #encoded data
    k_means = KMeans(n_clusters=10, random_state=40,init='k-means++', n_init=30, max_iter=500)
    #time_start = time.time()
    k_means.fit(X)
    #print('K-means done! Time elapsed: {} seconds'.format(time.time() - time_start))
    test_clusters = k_means.labels_
  

    
    score_nmi = normalized_mutual_info_score(y_train, test_clusters)
    score_ari=adjusted_rand_score(y_train, test_clusters)
    
    #print("ami k-means encoded data: ", score_ami+0.2)
    #print("nmi k-means encoded data: ", score_ari+0.2)
    return score_ari,score_nmi

# %%
import h5py
path='D:/m2/reduc/usps.h5'
with h5py.File(path, 'r') as hf:
        train = hf.get('train')
        X_tr = train.get('data')[:]
        y_tr = train.get('target')[:]
        test = hf.get('test')
        X_te = test.get('data')[:]
        y_te = test.get('target')[:]
maximum=0
for i in range(0,len(X_tr)):
    if(np.amax(X_tr[i])>maximum):
        maximum=np.amax(X_tr[0])
print(maximum)
x_train = X_tr.reshape((len(X_tr), np.prod(X_tr.shape[1:])))
x_test = X_te.reshape((len(X_te), np.prod(X_te.shape[1:])))
y_train=y_tr
y_test=y_te
# Out:
# 1.0

# %%
def tsne(per,X,y_train):
    import time
    from sklearn.manifold import TSNE
    
    #(x_train_encoded, y_train), (x_test_encoded, y_test) = get_encoded_data()
    time_start = time.time()
    print('encoded data')
    tsne = TSNE(n_components=2, verbose=1, perplexity=per, n_iter=250)
    tsne_results = tsne.fit_transform(X)
    figure, _, _, _ = fashion_scatter(tsne_results, y_train)
    figure.show()
    print('t-SNE done! Time elapsed: {} seconds'.format(time.time() - time_start))

# %%
nombre_classe = 10
dim=256

#creation deep ae
input_img = Input(shape=(dim,), name="inp_img")

encoded = Dense(256, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(32, activation='relu')(encoded)
bottlenek_layer=Dense(nombre_classe, activation='relu', name="bottleneck_layer")(encoded)
decoded = Dense(32, activation='relu')(bottlenek_layer)
decoded = Dense(64, activation='relu')(decoded)
decoded = Dense(256, activation='relu')(decoded)
output = Dense(dim, activation='sigmoid', name="logits")(decoded)
  


autoencoder = Model(input_img, decoded)

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(x_train)
ari,nmi=kmeans_fit(pca_result,y_train)
tsne(30,pca_result,y_train)
# Out:
# D:\annaconda\lib\site-packages\sklearn\metrics\cluster\supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# encoded data
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 7291 samples in 0.023s...
# [t-SNE] Computed neighbors for 7291 samples in 0.140s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7291
# [t-SNE] Computed conditional probabilities for sample 2000 / 7291
# [t-SNE] Computed conditional probabilities for sample 3000 / 7291
# [t-SNE] Computed conditional probabilities for sample 4000 / 7291
# [t-SNE] Computed conditional probabilities for sample 5000 / 7291
# [t-SNE] Computed conditional probabilities for sample 6000 / 7291
# [t-SNE] Computed conditional probabilities for sample 7000 / 7291
# [t-SNE] Computed conditional probabilities for sample 7291 / 7291
# [t-SNE] Mean sigma: 0.085719
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.235794
# [t-SNE] KL divergence after 251 iterations: .000000
# D:\annaconda\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()
# t-SNE done! Time elapsed: 20.666933298110962 seconds

# %%
print("ari= ",ari)
print("nmi= ",nmi)
# Out:
# ari=  0.35202191820336093
# nmi=  0.4491984372970025

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True)
ae = autoencoder.predict(x_test)
ari,nmi=kmeans_fit(ae,y_test)
tsne(30,ae,y_test)
# Out:
# WARNING:tensorflow:From D:\annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From D:\annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/50
# WARNING:tensorflow:From D:\annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From D:\annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From D:\annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From D:\annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From D:\annaconda\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 7291/7291 [==============================] - ETA: 1:21 - loss: 2.719 - ETA: 14s - loss: 2.371 - ETA: 6s - loss: 2.2132 - ETA: 3s - loss: 2.052 - ETA: 1s - loss: 1.949 - ETA: 0s - loss: 1.865 - 3s 452us/step - loss: 1.8343
# Epoch 2/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.558 - ETA: 0s - loss: 1.560 - ETA: 0s - loss: 1.559 - ETA: 0s - loss: 1.550 - ETA: 0s - loss: 1.546 - ETA: 0s - loss: 1.541 - 0s 46us/step - loss: 1.5388
# Epoch 3/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.465 - ETA: 0s - loss: 1.496 - ETA: 0s - loss: 1.510 - ETA: 0s - loss: 1.513 - ETA: 0s - loss: 1.516 - ETA: 0s - loss: 1.517 - ETA: 0s - loss: 1.517 - 0s 52us/step - loss: 1.5175
# Epoch 4/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.534 - ETA: 0s - loss: 1.501 - ETA: 0s - loss: 1.503 - ETA: 0s - loss: 1.497 - ETA: 0s - loss: 1.505 - ETA: 0s - loss: 1.508 - 0s 48us/step - loss: 1.5061
# Epoch 5/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.515 - ETA: 0s - loss: 1.518 - ETA: 0s - loss: 1.512 - ETA: 0s - loss: 1.498 - ETA: 0s - loss: 1.492 - ETA: 0s - loss: 1.491 - 0s 46us/step - loss: 1.4930
# Epoch 6/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.498 - ETA: 0s - loss: 1.475 - ETA: 0s - loss: 1.472 - ETA: 0s - loss: 1.466 - ETA: 0s - loss: 1.468 - ETA: 0s - loss: 1.470 - ETA: 0s - loss: 1.463 - ETA: 0s - loss: 1.465 - ETA: 0s - loss: 1.462 - 1s 72us/step - loss: 1.4621
# Epoch 7/50
# 7291/7291 [==============================] - ETA: 1s - loss: 1.462 - ETA: 0s - loss: 1.421 - ETA: 0s - loss: 1.424 - ETA: 0s - loss: 1.422 - ETA: 0s - loss: 1.423 - ETA: 0s - loss: 1.421 - ETA: 0s - loss: 1.418 - ETA: 0s - loss: 1.418 - ETA: 0s - loss: 1.412 - ETA: 0s - loss: 1.413 - ETA: 0s - loss: 1.416 - ETA: 0s - loss: 1.416 - 1s 105us/step - loss: 1.4170
# Epoch 8/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.422 - ETA: 0s - loss: 1.425 - ETA: 0s - loss: 1.416 - ETA: 0s - loss: 1.413 - ETA: 0s - loss: 1.397 - ETA: 0s - loss: 1.384 - ETA: 0s - loss: 1.376 - 0s 53us/step - loss: 1.3768
# Epoch 9/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.434 - ETA: 0s - loss: 1.432 - ETA: 0s - loss: 1.367 - ETA: 0s - loss: 1.337 - ETA: 0s - loss: 1.327 - ETA: 0s - loss: 1.317 - ETA: 0s - loss: 1.309 - ETA: 0s - loss: 1.303 - 0s 62us/step - loss: 1.2932
# Epoch 10/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.245 - ETA: 0s - loss: 1.258 - ETA: 0s - loss: 1.244 - ETA: 0s - loss: 1.244 - ETA: 0s - loss: 1.239 - ETA: 0s - loss: 1.236 - ETA: 0s - loss: 1.229 - 0s 52us/step - loss: 1.2290
# Epoch 11/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.263 - ETA: 0s - loss: 1.222 - ETA: 0s - loss: 1.213 - ETA: 0s - loss: 1.206 - ETA: 0s - loss: 1.214 - ETA: 0s - loss: 1.216 - ETA: 0s - loss: 1.213 - ETA: 0s - loss: 1.213 - 0s 59us/step - loss: 1.2137
# Epoch 12/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.141 - ETA: 0s - loss: 1.193 - ETA: 0s - loss: 1.198 - ETA: 0s - loss: 1.204 - ETA: 0s - loss: 1.205 - ETA: 0s - loss: 1.203 - ETA: 0s - loss: 1.203 - ETA: 0s - loss: 1.202 - 0s 58us/step - loss: 1.2023
# Epoch 13/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.153 - ETA: 0s - loss: 1.139 - ETA: 0s - loss: 1.156 - ETA: 0s - loss: 1.154 - ETA: 0s - loss: 1.150 - ETA: 0s - loss: 1.147 - ETA: 0s - loss: 1.147 - ETA: 0s - loss: 1.149 - 0s 68us/step - loss: 1.1476
# Epoch 14/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.147 - ETA: 0s - loss: 1.148 - ETA: 0s - loss: 1.151 - ETA: 0s - loss: 1.151 - ETA: 0s - loss: 1.147 - ETA: 0s - loss: 1.143 - ETA: 0s - loss: 1.139 - ETA: 0s - loss: 1.137 - 0s 60us/step - loss: 1.1374
# Epoch 15/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.139 - ETA: 0s - loss: 1.111 - ETA: 0s - loss: 1.108 - ETA: 0s - loss: 1.110 - ETA: 0s - loss: 1.111 - ETA: 0s - loss: 1.113 - ETA: 0s - loss: 1.113 - 0s 53us/step - loss: 1.1126
# Epoch 16/50
# 7291/7291 [==============================] - ETA: 1s - loss: 1.076 - ETA: 0s - loss: 1.094 - ETA: 0s - loss: 1.087 - ETA: 0s - loss: 1.097 - ETA: 0s - loss: 1.102 - ETA: 0s - loss: 1.102 - 0s 47us/step - loss: 1.1034
# Epoch 17/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.097 - ETA: 0s - loss: 1.087 - ETA: 0s - loss: 1.099 - ETA: 0s - loss: 1.096 - ETA: 0s - loss: 1.096 - ETA: 0s - loss: 1.096 - 0s 48us/step - loss: 1.0945
# Epoch 18/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.052 - ETA: 0s - loss: 1.084 - ETA: 0s - loss: 1.080 - ETA: 0s - loss: 1.084 - ETA: 0s - loss: 1.083 - ETA: 0s - loss: 1.093 - 0s 47us/step - loss: 1.0966
# Epoch 19/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.184 - ETA: 0s - loss: 1.151 - ETA: 0s - loss: 1.136 - ETA: 0s - loss: 1.114 - ETA: 0s - loss: 1.113 - ETA: 0s - loss: 1.108 - ETA: 0s - loss: 1.101 - 0s 52us/step - loss: 1.1013
# Epoch 20/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.037 - ETA: 0s - loss: 1.076 - ETA: 0s - loss: 1.080 - ETA: 0s - loss: 1.075 - ETA: 0s - loss: 1.073 - ETA: 0s - loss: 1.073 - ETA: 0s - loss: 1.071 - 0s 50us/step - loss: 1.0715
# Epoch 21/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.090 - ETA: 0s - loss: 1.072 - ETA: 0s - loss: 1.061 - ETA: 0s - loss: 1.046 - ETA: 0s - loss: 1.044 - ETA: 0s - loss: 1.047 - ETA: 0s - loss: 1.044 - ETA: 0s - loss: 1.045 - 0s 62us/step - loss: 1.0471
# Epoch 22/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.025 - ETA: 0s - loss: 1.054 - ETA: 0s - loss: 1.053 - ETA: 0s - loss: 1.050 - ETA: 0s - loss: 1.046 - ETA: 0s - loss: 1.044 - 0s 46us/step - loss: 1.0438
# Epoch 23/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.045 - ETA: 0s - loss: 1.039 - ETA: 0s - loss: 1.046 - ETA: 0s - loss: 1.043 - ETA: 0s - loss: 1.043 - ETA: 0s - loss: 1.041 - 0s 43us/step - loss: 1.0435
# Epoch 24/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.128 - ETA: 0s - loss: 1.094 - ETA: 0s - loss: 1.092 - ETA: 0s - loss: 1.087 - ETA: 0s - loss: 1.081 - ETA: 0s - loss: 1.075 - 0s 44us/step - loss: 1.0715
# Epoch 25/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.049 - ETA: 0s - loss: 1.053 - ETA: 0s - loss: 1.057 - ETA: 0s - loss: 1.054 - ETA: 0s - loss: 1.052 - 0s 38us/step - loss: 1.0510
# Epoch 26/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.005 - ETA: 0s - loss: 1.029 - ETA: 0s - loss: 1.043 - ETA: 0s - loss: 1.043 - ETA: 0s - loss: 1.040 - ETA: 0s - loss: 1.041 - ETA: 0s - loss: 1.042 - 0s 52us/step - loss: 1.0411
# Epoch 27/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.045 - ETA: 0s - loss: 1.047 - ETA: 0s - loss: 1.041 - ETA: 0s - loss: 1.055 - ETA: 0s - loss: 1.058 - ETA: 0s - loss: 1.058 - ETA: 0s - loss: 1.059 - ETA: 0s - loss: 1.054 - ETA: 0s - loss: 1.049 - 0s 68us/step - loss: 1.0484
# Epoch 28/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.046 - ETA: 2s - loss: 1.061 - ETA: 1s - loss: 1.068 - ETA: 1s - loss: 1.055 - ETA: 0s - loss: 1.050 - ETA: 0s - loss: 1.050 - ETA: 0s - loss: 1.044 - ETA: 0s - loss: 1.042 - 1s 78us/step - loss: 1.0421
# Epoch 29/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.034 - ETA: 0s - loss: 1.041 - ETA: 0s - loss: 1.029 - ETA: 0s - loss: 1.031 - ETA: 0s - loss: 1.026 - ETA: 0s - loss: 1.027 - ETA: 0s - loss: 1.025 - 0s 57us/step - loss: 1.0244
# Epoch 30/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.012 - ETA: 0s - loss: 1.025 - ETA: 0s - loss: 1.028 - ETA: 0s - loss: 1.017 - ETA: 0s - loss: 1.014 - 0s 43us/step - loss: 1.0155
# Epoch 31/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.047 - ETA: 0s - loss: 1.010 - ETA: 0s - loss: 1.018 - ETA: 0s - loss: 1.016 - ETA: 0s - loss: 1.013 - 0s 42us/step - loss: 1.0148
# Epoch 32/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.981 - ETA: 0s - loss: 1.005 - ETA: 0s - loss: 1.005 - ETA: 0s - loss: 1.006 - ETA: 0s - loss: 1.004 - ETA: 0s - loss: 1.010 - 0s 41us/step - loss: 1.0105
# Epoch 33/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.042 - ETA: 0s - loss: 1.020 - ETA: 0s - loss: 1.013 - ETA: 0s - loss: 1.007 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.007 - ETA: 0s - loss: 1.009 - 0s 60us/step - loss: 1.0082
# Epoch 34/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.037 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.007 - ETA: 0s - loss: 1.005 - 0s 43us/step - loss: 1.0062
# Epoch 35/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.943 - ETA: 0s - loss: 0.994 - ETA: 0s - loss: 0.992 - ETA: 0s - loss: 1.002 - ETA: 0s - loss: 1.003 - 0s 40us/step - loss: 1.0053
# Epoch 36/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.050 - ETA: 0s - loss: 1.036 - ETA: 0s - loss: 1.022 - ETA: 0s - loss: 1.012 - ETA: 0s - loss: 1.006 - ETA: 0s - loss: 1.005 - ETA: 0s - loss: 1.004 - 0s 63us/step - loss: 1.0050
# Epoch 37/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.047 - ETA: 0s - loss: 1.001 - ETA: 0s - loss: 1.000 - ETA: 0s - loss: 1.004 - ETA: 0s - loss: 1.006 - ETA: 0s - loss: 1.005 - ETA: 0s - loss: 1.002 - ETA: 0s - loss: 1.003 - 0s 62us/step - loss: 1.0027
# Epoch 38/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.019 - ETA: 0s - loss: 1.007 - ETA: 0s - loss: 1.007 - ETA: 0s - loss: 1.016 - ETA: 0s - loss: 1.014 - ETA: 0s - loss: 1.015 - ETA: 0s - loss: 1.016 - ETA: 0s - loss: 1.014 - 0s 63us/step - loss: 1.0134
# Epoch 39/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.980 - ETA: 0s - loss: 1.016 - ETA: 0s - loss: 1.010 - ETA: 0s - loss: 1.014 - ETA: 0s - loss: 1.012 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.009 - 0s 49us/step - loss: 1.0104
# Epoch 40/50
# 7291/7291 [==============================] - ETA: 1s - loss: 0.969 - ETA: 1s - loss: 0.989 - ETA: 0s - loss: 1.004 - ETA: 0s - loss: 1.009 - ETA: 0s - loss: 1.009 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.010 - ETA: 0s - loss: 1.010 - 1s 70us/step - loss: 1.0087
# Epoch 41/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.973 - ETA: 0s - loss: 1.011 - ETA: 0s - loss: 1.015 - ETA: 0s - loss: 1.003 - ETA: 0s - loss: 1.003 - ETA: 0s - loss: 1.005 - ETA: 0s - loss: 1.006 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.007 - 0s 68us/step - loss: 1.0071
# Epoch 42/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.015 - ETA: 0s - loss: 1.004 - ETA: 0s - loss: 1.009 - ETA: 0s - loss: 1.006 - ETA: 0s - loss: 1.002 - ETA: 0s - loss: 0.999 - ETA: 0s - loss: 1.000 - ETA: 0s - loss: 1.003 - ETA: 0s - loss: 1.004 - ETA: 0s - loss: 1.005 - 1s 80us/step - loss: 1.0044
# Epoch 43/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.989 - ETA: 0s - loss: 0.981 - ETA: 0s - loss: 0.988 - ETA: 0s - loss: 1.025 - ETA: 0s - loss: 1.061 - ETA: 0s - loss: 1.068 - ETA: 0s - loss: 1.073 - ETA: 0s - loss: 1.076 - ETA: 0s - loss: 1.076 - ETA: 0s - loss: 1.074 - ETA: 0s - loss: 1.074 - 1s 110us/step - loss: 1.0739
# Epoch 44/50
# 7291/7291 [==============================] - ETA: 1s - loss: 1.029 - ETA: 1s - loss: 1.026 - ETA: 1s - loss: 1.035 - ETA: 1s - loss: 1.048 - ETA: 1s - loss: 1.040 - ETA: 1s - loss: 1.041 - ETA: 0s - loss: 1.029 - ETA: 0s - loss: 1.030 - ETA: 0s - loss: 1.027 - ETA: 0s - loss: 1.025 - ETA: 0s - loss: 1.019 - ETA: 0s - loss: 1.019 - ETA: 0s - loss: 1.019 - ETA: 0s - loss: 1.018 - ETA: 0s - loss: 1.018 - 1s 141us/step - loss: 1.0176
# Epoch 45/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.964 - ETA: 0s - loss: 0.973 - ETA: 0s - loss: 0.969 - ETA: 0s - loss: 0.977 - ETA: 0s - loss: 0.983 - ETA: 0s - loss: 0.984 - ETA: 0s - loss: 0.985 - ETA: 0s - loss: 0.990 - ETA: 0s - loss: 0.998 - ETA: 0s - loss: 1.005 - ETA: 0s - loss: 1.009 - 1s 89us/step - loss: 1.0122
# Epoch 46/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.978 - ETA: 0s - loss: 1.010 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.007 - ETA: 0s - loss: 1.008 - ETA: 0s - loss: 1.004 - ETA: 0s - loss: 1.004 - 0s 58us/step - loss: 1.0052
# Epoch 47/50
# 7291/7291 [==============================] - ETA: 1s - loss: 1.009 - ETA: 0s - loss: 0.984 - ETA: 0s - loss: 0.976 - ETA: 0s - loss: 0.977 - ETA: 0s - loss: 0.978 - ETA: 0s - loss: 0.978 - ETA: 0s - loss: 0.978 - ETA: 0s - loss: 0.979 - ETA: 0s - loss: 0.977 - 1s 71us/step - loss: 0.9789
# Epoch 48/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.945 - ETA: 0s - loss: 0.966 - ETA: 0s - loss: 0.960 - ETA: 0s - loss: 0.964 - ETA: 0s - loss: 0.967 - ETA: 0s - loss: 0.965 - 0s 53us/step - loss: 0.9638
# Epoch 49/50
# 7291/7291 [==============================] - ETA: 0s - loss: 1.007 - ETA: 0s - loss: 0.966 - ETA: 0s - loss: 0.958 - ETA: 0s - loss: 0.948 - ETA: 0s - loss: 0.950 - ETA: 0s - loss: 0.954 - 0s 46us/step - loss: 0.9558
# Epoch 50/50
# 7291/7291 [==============================] - ETA: 0s - loss: 0.951 - ETA: 0s - loss: 0.949 - ETA: 0s - loss: 0.957 - ETA: 0s - loss: 0.962 - ETA: 0s - loss: 0.970 - ETA: 0s - loss: 0.975 - ETA: 0s - loss: 0.979 - 0s 50us/step - loss: 0.9781
# D:\annaconda\lib\site-packages\sklearn\metrics\cluster\supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# encoded data
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2007 samples in 0.053s...
# [t-SNE] Computed neighbors for 2007 samples in 0.953s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2007
# [t-SNE] Computed conditional probabilities for sample 2000 / 2007
# [t-SNE] Computed conditional probabilities for sample 2007 / 2007
# [t-SNE] Mean sigma: 0.418588
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.308456
# [t-SNE] KL divergence after 251 iterations: .000000
# D:\annaconda\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()
# t-SNE done! Time elapsed: 5.3317060470581055 seconds

# %%
print("ari= ",ari)
print("nmi= ",nmi)
# Out:
# ari=  0.2775537419452632
# nmi=  0.443250539465251

# %%
S = manifold.LocallyLinearEmbedding(n_neighbors=3, n_components=2,
                                        eigen_solver='auto',
                                        method='standard').fit_transform(x_train)
ari,nmi=kmeans_fit(S,y_train)
tsne(30,S ,y_train)
# Out:
# D:\annaconda\lib\site-packages\sklearn\metrics\cluster\supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# encoded data
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2007 samples in 0.001s...
# [t-SNE] Computed neighbors for 2007 samples in 0.042s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2007
# [t-SNE] Computed conditional probabilities for sample 2000 / 2007
# [t-SNE] Computed conditional probabilities for sample 2007 / 2007
# [t-SNE] Mean sigma: 0.001430
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.496922
# [t-SNE] KL divergence after 251 iterations: .000000
# D:\annaconda\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()
# t-SNE done! Time elapsed: 4.784268140792847 seconds

# %%
print("ari= ",ari)
print("nmi= ",nmi)
# Out:
# ari=  0.3334382790952595
# nmi=  0.48803663533891894
